# %%
import pandas as pd
from skbio import TreeNode
from os.path import join, basename
from collections import OrderedDict
from os import makedirs
from glob import glob
from shutil import copytree

# %% [markdown]
# # Prepare GWCodeML scripts and file
#
# This notebook reads in the set of calculated per-clade genome-wide symbiont trees, reroots them based on the complete marker gene-based symbiont supertree, and identifies the branches of the symbiont tree leading to monophyletic clades of symbiont genomes from target host species, if they exist.
#
# Uses this information to creat per-clade input files to GWCodeML

# %%
trees_dir = '../data/renamed/symbiont_trees/'

# %%
def count_clade_hosts(tree, focal_host):
    '''
    
    '''
    tips = [x.name for x in tree.tips()]
    spp = [x[0:6] for x in tips]
    focal_tips = sum([x == focal_host for x in spp])
    if focal_tips == 0:
        return(None)
    
    tree.assign_ids()
    clade_counts = {}
    for clade in tree.postorder():
        if clade.is_tip():
            clade_tips = [clade.name]
        else:
            clade_tips = [x.name for x in clade.tips()]
        clade_spp = [x[0:6] for x in clade_tips]
        clade_focal_tips = sum([x == focal_host for x in clade_spp])
        clade_counts[clade.id] = {'id': clade.id,
                                  'tips': len(clade_tips),
                                  'focal_tips': clade_focal_tips,
                                  'prop_of_foci': clade_focal_tips / focal_tips,
                                  'focal_prop': clade_focal_tips / len(clade_tips)}
    
    clade_df = pd.DataFrame.from_dict(clade_counts, orient='index')
    
    return(clade_df)

# %%
tree_fps = glob(join(trees_dir, '*.nwk'))

# %%
trees = {}

# %%
trees = {}
dfs = []
focus = 'homsap'

for tree_fp in tree_fps:
    tree = TreeNode.read(tree_fp, 
                         convert_underscores=False)
    cluster = int(basename(tree_fp).split('.')[0].split('_')[1])
    cluster_df = count_clade_hosts(tree, focus)
    if cluster_df is not None:
        trees[cluster] = tree
        cluster_df['cluster'] = cluster
        dfs.append(cluster_df)

# %% [markdown]
# ## Root trees
#
# Root subtrees based on rooting position in whole marker gene tree

# %%
super_tree_fp = '../data/renamed/gtdbtk.bac120.user_msa.fasta.treefile.renamed.tre'

super_tree = TreeNode.read(super_tree_fp,
                           convert_underscores=False)

# %%
def reroot(target, source):
    target_outgroups = []
    for child in target.children:
        if child.is_tip():
            target_outgroups.append(child.name)

    for child in source.children:
        if child.is_tip():
            if child.name in target_outgroups:
                return(target)
            else:
                return(target.root_at(target.find(child.name).parent))
        tips = [x.name for x in child.tips()]
        target_node = target.lowest_common_ancestor(tips)
        if len([x for x in target_node.tips()]) == len(tips):
            return(target.root_at(target_node))
    raise ValueError

# %%
rerooted = {}

for clade in trees:
    tree = trees[clade]
    super_clade = super_tree.lowest_common_ancestor([x.name for x in tree.tips()])
    try:
        rerooted[clade] = reroot(tree, super_clade)
    except:
        print("Failure on clade %s\n" % clade)
#         print("Target tree:\n")
#         print(tree.ascii_art())
#         print("Source tree:\n")
#         print(super_clade.ascii_art())
# Out:
# Failure on clade 30
#
# Failure on clade 73

# %% [markdown]
# ## Find and mark branches

# %%
host_dfs = {}
target_genera = ['hom', 'pan']

for clade in rerooted:
    tree = rerooted[clade]
    tips = [x.name for x in tree.tips()]
    gen = []
    spp = []
    for tip in tips:
        gen.append(tip[0:3])
        spp.append(tip[3:6])
    clade_df = pd.DataFrame.from_dict({'Tip': tips,
                                       'Genus': gen,
                                       'Species': spp})
    clade_df['Clade'] = clade
    clade_df['Branch'] = 0
    host_dfs[clade] = clade_df
    
    for i, target in enumerate(target_genera):
        target_tips = list(clade_df.loc[clade_df['Genus'] == target, 'Tip'])
        if len(target_tips) < 1:
            continue
        if len(target_tips) == 1:
            clade_df.loc[clade_df['Tip'] == target_tips[0], 'Branch'] = i + 1
            continue
        target_node = tree.lowest_common_ancestor(target_tips)
        lca_tips = [x.name for x in target_node.tips()]
        if len(lca_tips) == len(target_tips):
            clade_df.loc[clade_df['Tip'].isin(target_tips), 'Branch'] = i + 1

# %%
host_dfs
# Out:
# {10:           Tip Genus Species  Clade  Branch
#  0  homsap3623   hom     sap     10       0
#  1  homsap3621   hom     sap     10       0
#  2  homsap3622   hom     sap     10       0
#  3  homsap3620   hom     sap     10       0
#  4  homsap3619   hom     sap     10       0
#  5  homsap3618   hom     sap     10       0
#  6  prover0048   pro     ver     10       0
#  7  prover0049   pro     ver     10       0
#  8  alosen0026   alo     sen     10       0,
#  100:           Tip Genus Species  Clade  Branch
#  0  homsap0516   hom     sap    100       1
#  1  panpan0185   pan     pan    100       2
#  2  panpan0186   pan     pan    100       2
#  3  pantro0129   pan     tro    100       2
#  4  pantro0127   pan     tro    100       2
#  5  pantro0128   pan     tro    100       2
#  6  gorgor0025   gor     gor    100       0,
#  167:            Tip Genus Species  Clade  Branch
#  0   pantro0231   pan     tro    167       0
#  1   pantro0232   pan     tro    167       0
#  2   pansch0352   pan     sch    167       0
#  3   pansch0351   pan     sch    167       0
#  4   pansch0350   pan     sch    167       0
#  5   pansch0354   pan     sch    167       0
#  6   pansch0353   pan     sch    167       0
#  7   panpan0291   pan     pan    167       0
#  8   panpan0290   pan     pan    167       0
#  9   panpan0292   pan     pan    167       0
#  10  homsap1106   hom     sap    167       1,
#  119:            Tip Genus Species  Clade  Branch
#  0   homsap3825   hom     sap    119       0
#  1   papcyn0743   pap     cyn    119       0
#  2   homsap3826   hom     sap    119       0
#  3   pantro0432   pan     tro    119       0
#  4   homsap3827   hom     sap    119       0
#  5   pansch0754   pan     sch    119       0
#  6   panpan0613   pan     pan    119       0
#  7   alopig0073   alo     pig    119       0
#  8   alopig0072   alo     pig    119       0
#  9   alopig0071   alo     pig    119       0
#  10  alopig0070   alo     pig    119       0
#  11  alocar0017   alo     car    119       0,
#  192:           Tip Genus Species  Clade  Branch
#  0  panpan0001   pan     pan    192       2
#  1  pansch0001   pan     sch    192       2
#  2  homsap0005   hom     sap    192       1
#  3  homsap0003   hom     sap    192       1
#  4  homsap0002   hom     sap    192       1
#  5  homsap0004   hom     sap    192       1
#  6  colgue0000   col     gue    192       0,
#  109:            Tip Genus Species  Clade  Branch
#  0   panpan0242   pan     pan    109       0
#  1   panpan0243   pan     pan    109       0
#  2   panpan0244   pan     pan    109       0
#  3   panpan0241   pan     pan    109       0
#  4   panpan0240   pan     pan    109       0
#  5   panpan0239   pan     pan    109       0
#  6   pantro0181   pan     tro    109       0
#  7   pantro0180   pan     tro    109       0
#  8   pantro0179   pan     tro    109       0
#  9   pantro0182   pan     tro    109       0
#  10  pantro0183   pan     tro    109       0
#  11  panpan0238   pan     pan    109       0
#  12  pansch0280   pan     sch    109       0
#  13  pansch0281   pan     sch    109       0
#  14  pansch0289   pan     sch    109       0
#  15  pansch0278   pan     sch    109       0
#  16  pansch0279   pan     sch    109       0
#  17  pansch0287   pan     sch    109       0
#  18  pansch0286   pan     sch    109       0
#  19  pansch0288   pan     sch    109       0
#  20  pansch0283   pan     sch    109       0
#  21  pansch0284   pan     sch    109       0
#  22  pansch0285   pan     sch    109       0
#  23  pansch0282   pan     sch    109       0
#  24  homsap0853   hom     sap    109       1,
#  158:           Tip Genus Species  Clade  Branch
#  0  pantro0227   pan     tro    158       2
#  1  pantro0226   pan     tro    158       2
#  2  pantro0228   pan     tro    158       2
#  3  pantro0229   pan     tro    158       2
#  4  pantro0230   pan     tro    158       2
#  5  panpan0289   pan     pan    158       2
#  6  pansch0349   pan     sch    158       2
#  7  homsap1057   hom     sap    158       1
#  8  gorgor0084   gor     gor    158       0
#  9  gorgor0083   gor     gor    158       0,
#  80:            Tip Genus Species  Clade  Branch
#  0   papcyn0419   pap     cyn     80       0
#  1   papcyn0420   pap     cyn     80       0
#  2   papcyn0417   pap     cyn     80       0
#  3   papcyn0418   pap     cyn     80       0
#  4   papcyn0424   pap     cyn     80       0
#  5   papcyn0423   pap     cyn     80       0
#  6   papcyn0421   pap     cyn     80       0
#  7   papcyn0422   pap     cyn     80       0
#  8   homsap0992   hom     sap     80       0
#  9   homsap0991   hom     sap     80       0
#  10  alopal0037   alo     pal     80       0
#  11  alopal0036   alo     pal     80       0,
#  94:           Tip Genus Species  Clade  Branch
#  0  pantro0086   pan     tro     94       0
#  1  pansch0141   pan     sch     94       0
#  2  pansch0142   pan     sch     94       0
#  3  pansch0140   pan     sch     94       0
#  4  pansch0139   pan     sch     94       0
#  5  panpan0143   pan     pan     94       0
#  6  panpan0144   pan     pan     94       0
#  7  panpan0145   pan     pan     94       0
#  8  panpan0146   pan     pan     94       0
#  9  homsap0384   hom     sap     94       1,
#  108:           Tip Genus Species  Clade  Branch
#  0  homsap2822   hom     sap    108       0
#  1  homsap2823   hom     sap    108       0
#  2  homsap2824   hom     sap    108       0
#  3  homsap2821   hom     sap    108       0
#  4  homsap2820   hom     sap    108       0
#  5  homsap2819   hom     sap    108       0
#  6  prover0045   pro     ver    108       0
#  7  prover0046   pro     ver    108       0
#  8  prover0047   pro     ver    108       0
#  9  atehyb0018   ate     hyb    108       0,
#  159:            Tip Genus Species  Clade  Branch
#  0   pantro0425   pan     tro    159       0
#  1   pantro0424   pan     tro    159       0
#  2   pantro0422   pan     tro    159       0
#  3   pantro0423   pan     tro    159       0
#  4   pansch0736   pan     sch    159       0
#  5   pansch0735   pan     sch    159       0
#  6   panpan0597   pan     pan    159       0
#  7   panpan0591   pan     pan    159       0
#  8   panpan0596   pan     pan    159       0
#  9   panpan0592   pan     pan    159       0
#  10  panpan0595   pan     pan    159       0
#  11  panpan0594   pan     pan    159       0
#  12  panpan0593   pan     pan    159       0
#  13  homsap3754   hom     sap    159       1,
#  188:            Tip Genus Species  Clade  Branch
#  0   panpan0356   pan     pan    188       0
#  1   pantro0262   pan     tro    188       0
#  2   pansch0462   pan     sch    188       0
#  3   pansch0464   pan     sch    188       0
#  4   pansch0465   pan     sch    188       0
#  5   pansch0466   pan     sch    188       0
#  6   pansch0460   pan     sch    188       0
#  7   pansch0461   pan     sch    188       0
#  8   pansch0463   pan     sch    188       0
#  9   homsap1964   hom     sap    188       1
#  10  homsap1962   hom     sap    188       1
#  11  homsap1963   hom     sap    188       1,
#  92:            Tip Genus Species  Clade  Branch
#  0   pansch0115   pan     sch     92       0
#  1   pansch0116   pan     sch     92       0
#  2   pansch0117   pan     sch     92       0
#  3   pantro0055   pan     tro     92       0
#  4   pantro0056   pan     tro     92       0
#  5   pantro0057   pan     tro     92       0
#  6   pantro0058   pan     tro     92       0
#  7   pansch0114   pan     sch     92       0
#  8   pansch0112   pan     sch     92       0
#  9   pansch0113   pan     sch     92       0
#  10  homsap0313   hom     sap     92       1
#  11  homsap0312   hom     sap     92       1
#  12  homsap0311   hom     sap     92       1,
#  81:            Tip Genus Species  Clade  Branch
#  0   papcyn0723   pap     cyn     81       0
#  1   papcyn0717   pap     cyn     81       0
#  2   papcyn0719   pap     cyn     81       0
#  3   papcyn0721   pap     cyn     81       0
#  4   papcyn0722   pap     cyn     81       0
#  5   papcyn0714   pap     cyn     81       0
#  6   papcyn0715   pap     cyn     81       0
#  7   papcyn0716   pap     cyn     81       0
#  8   papcyn0720   pap     cyn     81       0
#  9   papcyn0718   pap     cyn     81       0
#  10  pantro0383   pan     tro     81       2
#  11  pansch0676   pan     sch     81       2
#  12  pansch0671   pan     sch     81       2
#  13  pansch0675   pan     sch     81       2
#  14  pansch0670   pan     sch     81       2
#  15  pansch0669   pan     sch     81       2
#  16  pansch0679   pan     sch     81       2
#  17  pansch0678   pan     sch     81       2
#  18  panpan0541   pan     pan     81       2
#  19  pansch0677   pan     sch     81       2
#  20  pansch0672   pan     sch     81       2
#  21  pansch0674   pan     sch     81       2
#  22  pansch0673   pan     sch     81       2
#  23  pantro0384   pan     tro     81       2
#  24  homsap3372   hom     sap     81       1
#  25  homsap3373   hom     sap     81       1
#  26  homsap3374   hom     sap     81       1
#  27  homsap3375   hom     sap     81       1
#  28  homsap3376   hom     sap     81       1,
#  96:            Tip Genus Species  Clade  Branch
#  0   pantro0358   pan     tro     96       0
#  1   panpan0503   pan     pan     96       0
#  2   panpan0500   pan     pan     96       0
#  3   panpan0502   pan     pan     96       0
#  4   panpan0501   pan     pan     96       0
#  5   panpan0504   pan     pan     96       0
#  6   panpan0505   pan     pan     96       0
#  7   panpan0506   pan     pan     96       0
#  8   panpan0499   pan     pan     96       0
#  9   panpan0498   pan     pan     96       0
#  10  pansch0616   pan     sch     96       0
#  11  pansch0617   pan     sch     96       0
#  12  pansch0618   pan     sch     96       0
#  13  pansch0611   pan     sch     96       0
#  14  pansch0610   pan     sch     96       0
#  15  pansch0613   pan     sch     96       0
#  16  pansch0612   pan     sch     96       0
#  17  pansch0614   pan     sch     96       0
#  18  pansch0615   pan     sch     96       0
#  19  homsap2863   hom     sap     96       1,
#  111:            Tip Genus Species  Clade  Branch
#  0   pansch0186   pan     sch    111       0
#  1   pansch0185   pan     sch    111       0
#  2   panpan0182   pan     pan    111       0
#  3   pansch0188   pan     sch    111       0
#  4   pansch0187   pan     sch    111       0
#  5   pantro0121   pan     tro    111       0
#  6   pantro0120   pan     tro    111       0
#  7   pantro0122   pan     tro    111       0
#  8   pantro0123   pan     tro    111       0
#  9   panpan0184   pan     pan    111       0
#  10  panpan0183   pan     pan    111       0
#  11  homsap0499   hom     sap    111       1,
#  67:           Tip Genus Species  Clade  Branch
#  0  panpan0754   pan     pan     67       0
#  1  panpan0753   pan     pan     67       0
#  2  pantro0526   pan     tro     67       0
#  3  pansch0903   pan     sch     67       0
#  4  pansch0902   pan     sch     67       0
#  5  panpan0755   pan     pan     67       0
#  6  pansch0904   pan     sch     67       0
#  7  homsap4348   hom     sap     67       1
#  8  homsap4349   hom     sap     67       1,
#  82:            Tip Genus Species  Clade  Branch
#  0   pansch0207   pan     sch     82       0
#  1   pansch0206   pan     sch     82       0
#  2   panpan0199   pan     pan     82       0
#  3   papcyn0275   pap     cyn     82       0
#  4   papcyn0274   pap     cyn     82       0
#  5   papcyn0277   pap     cyn     82       0
#  6   papcyn0280   pap     cyn     82       0
#  7   papcyn0279   pap     cyn     82       0
#  8   papcyn0273   pap     cyn     82       0
#  9   papcyn0281   pap     cyn     82       0
#  10  papcyn0278   pap     cyn     82       0
#  11  papcyn0276   pap     cyn     82       0
#  12  homsap0528   hom     sap     82       1,
#  132:            Tip Genus Species  Clade  Branch
#  0   papcyn0234   pap     cyn    132       0
#  1   papcyn0236   pap     cyn    132       0
#  2   papcyn0232   pap     cyn    132       0
#  3   papcyn0226   pap     cyn    132       0
#  4   papcyn0230   pap     cyn    132       0
#  5   papcyn0229   pap     cyn    132       0
#  6   papcyn0231   pap     cyn    132       0
#  7   papcyn0237   pap     cyn    132       0
#  8   papcyn0228   pap     cyn    132       0
#  9   papcyn0233   pap     cyn    132       0
#  10  papcyn0227   pap     cyn    132       0
#  11  papcyn0225   pap     cyn    132       0
#  12  papcyn0235   pap     cyn    132       0
#  13  papcyn0238   pap     cyn    132       0
#  14  panpan0168   pan     pan    132       2
#  15  pansch0169   pan     sch    132       2
#  16  pansch0170   pan     sch    132       2
#  17  pantro0113   pan     tro    132       2
#  18  pantro0111   pan     tro    132       2
#  19  pantro0112   pan     tro    132       2
#  20  homsap0478   hom     sap    132       1,
#  19:            Tip Genus Species  Clade  Branch
#  0   panpan0292   pan     pan     19       2
#  1   panpan0291   pan     pan     19       2
#  2   panpan0290   pan     pan     19       2
#  3   pantro0232   pan     tro     19       2
#  4   pantro0231   pan     tro     19       2
#  5   pansch0354   pan     sch     19       2
#  6   pansch0353   pan     sch     19       2
#  7   pansch0350   pan     sch     19       2
#  8   pansch0351   pan     sch     19       2
#  9   pansch0352   pan     sch     19       2
#  10  homsap1105   hom     sap     19       0
#  11  homsap1106   hom     sap     19       0,
#  68:           Tip Genus Species  Clade  Branch
#  0  pantro0489   pan     tro     68       0
#  1  panpan0692   pan     pan     68       0
#  2  panpan0691   pan     pan     68       0
#  3  homsap4061   hom     sap     68       1
#  4  homsap4063   hom     sap     68       1
#  5  homsap4064   hom     sap     68       1
#  6  homsap4062   hom     sap     68       1,
#  83:            Tip Genus Species  Clade  Branch
#  0   pansch0266   pan     sch     83       2
#  1   pansch0265   pan     sch     83       2
#  2   panpan0233   pan     pan     83       2
#  3   pansch0264   pan     sch     83       2
#  4   pantro0175   pan     tro     83       2
#  5   panpan0231   pan     pan     83       2
#  6   panpan0230   pan     pan     83       2
#  7   panpan0232   pan     pan     83       2
#  8   panpan0228   pan     pan     83       2
#  9   panpan0229   pan     pan     83       2
#  10  pantro0168   pan     tro     83       2
#  11  pantro0167   pan     tro     83       2
#  12  pantro0170   pan     tro     83       2
#  13  pantro0169   pan     tro     83       2
#  14  pantro0171   pan     tro     83       2
#  15  pantro0173   pan     tro     83       2
#  16  pantro0172   pan     tro     83       2
#  17  pantro0174   pan     tro     83       2
#  18  pansch0263   pan     sch     83       2
#  19  pansch0260   pan     sch     83       2
#  20  pansch0261   pan     sch     83       2
#  21  pansch0262   pan     sch     83       2
#  22  gorgor0037   gor     gor     83       0
#  23  homsap0844   hom     sap     83       1
#  24  papcyn0351   pap     cyn     83       0
#  25  papcyn0347   pap     cyn     83       0
#  26  papcyn0343   pap     cyn     83       0
#  27  papcyn0344   pap     cyn     83       0
#  28  papcyn0346   pap     cyn     83       0
#  29  papcyn0345   pap     cyn     83       0
#  30  papcyn0348   pap     cyn     83       0
#  31  papcyn0352   pap     cyn     83       0
#  32  papcyn0349   pap     cyn     83       0
#  33  papcyn0350   pap     cyn     83       0
#  34  papham0007   pap     ham     83       0,
#  112:            Tip Genus Species  Clade  Branch
#  0   homsap0853   hom     sap    112       0
#  1   panpan0241   pan     pan    112       2
#  2   panpan0240   pan     pan    112       2
#  3   panpan0239   pan     pan    112       2
#  4   panpan0242   pan     pan    112       2
#  5   panpan0244   pan     pan    112       2
#  6   panpan0243   pan     pan    112       2
#  7   pantro0182   pan     tro    112       2
#  8   pantro0183   pan     tro    112       2
#  9   pantro0180   pan     tro    112       2
#  10  pantro0179   pan     tro    112       2
#  11  pantro0181   pan     tro    112       2
#  12  pansch0289   pan     sch    112       2
#  13  panpan0238   pan     pan    112       2
#  14  pansch0278   pan     sch    112       2
#  15  pansch0279   pan     sch    112       2
#  16  pansch0281   pan     sch    112       2
#  17  pansch0280   pan     sch    112       2
#  18  pansch0285   pan     sch    112       2
#  19  pansch0282   pan     sch    112       2
#  20  pansch0284   pan     sch    112       2
#  21  pansch0283   pan     sch    112       2
#  22  pansch0287   pan     sch    112       2
#  23  pansch0288   pan     sch    112       2
#  24  pansch0286   pan     sch    112       2
#  25  homsap0852   hom     sap    112       0
#  26  homsap0851   hom     sap    112       0
#  27  homsap0855   hom     sap    112       0
#  28  homsap0854   hom     sap    112       0,
#  133:            Tip Genus Species  Clade  Branch
#  0   panpan0449   pan     pan    133       0
#  1   panpan0448   pan     pan    133       0
#  2   pantro0318   pan     tro    133       0
#  3   pantro0319   pan     tro    133       0
#  4   pansch0545   pan     sch    133       0
#  5   panpan0447   pan     pan    133       0
#  6   pansch0544   pan     sch    133       0
#  7   pansch0542   pan     sch    133       0
#  8   pansch0541   pan     sch    133       0
#  9   pansch0543   pan     sch    133       0
#  10  homsap2808   hom     sap    133       1
#  11  homsap2807   hom     sap    133       1,
#  165:            Tip Genus Species  Clade  Branch
#  0   panpan0429   pan     pan    165       0
#  1   panpan0430   pan     pan    165       0
#  2   pansch0519   pan     sch    165       0
#  3   pansch0517   pan     sch    165       0
#  4   pansch0520   pan     sch    165       0
#  5   pansch0518   pan     sch    165       0
#  6   pansch0521   pan     sch    165       0
#  7   pansch0522   pan     sch    165       0
#  8   pantro0306   pan     tro    165       0
#  9   pantro0305   pan     tro    165       0
#  10  pantro0304   pan     tro    165       0
#  11  pantro0307   pan     tro    165       0
#  12  pantro0308   pan     tro    165       0
#  13  homsap2766   hom     sap    165       1
#  14  homsap2767   hom     sap    165       1
#  15  homsap2762   hom     sap    165       1
#  16  homsap2761   hom     sap    165       1
#  17  homsap2760   hom     sap    165       1
#  18  homsap2759   hom     sap    165       1
#  19  homsap2763   hom     sap    165       1
#  20  homsap2765   hom     sap    165       1
#  21  homsap2764   hom     sap    165       1,
#  23:            Tip Genus Species  Clade  Branch
#  0   homsap2752   hom     sap     23       0
#  1   pantro0303   pan     tro     23       2
#  2   pantro0302   pan     tro     23       2
#  3   pantro0301   pan     tro     23       2
#  4   pansch0514   pan     sch     23       2
#  5   pansch0516   pan     sch     23       2
#  6   panpan0427   pan     pan     23       2
#  7   pansch0513   pan     sch     23       2
#  8   pansch0515   pan     sch     23       2
#  9   pansch0511   pan     sch     23       2
#  10  pansch0512   pan     sch     23       2
#  11  panpan0428   pan     pan     23       2
#  12  homsap2753   hom     sap     23       0,
#  4:            Tip Genus Species  Clade  Branch
#  0   pilbad0001   pil     bad      4       0
#  1   colgue0003   col     gue      4       0
#  2   prover0002   pro     ver      4       0
#  3   prover0000   pro     ver      4       0
#  4   prover0001   pro     ver      4       0
#  5   prover0003   pro     ver      4       0
#  6   panpan0101   pan     pan      4       2
#  7   panpan0102   pan     pan      4       2
#  8   panpan0105   pan     pan      4       2
#  9   panpan0104   pan     pan      4       2
#  10  panpan0103   pan     pan      4       2
#  11  pansch0089   pan     sch      4       2
#  12  pansch0093   pan     sch      4       2
#  13  panpan0100   pan     pan      4       2
#  14  pansch0091   pan     sch      4       2
#  15  pansch0092   pan     sch      4       2
#  16  pansch0090   pan     sch      4       2
#  17  pantro0036   pan     tro      4       2
#  18  pansch0094   pan     sch      4       2
#  19  homsap0293   hom     sap      4       1
#  20  atehyb0000   ate     hyb      4       0
#  21  alosen0008   alo     sen      4       0
#  22  alopig0013   alo     pig      4       0
#  23  alopig0012   alo     pig      4       0
#  24  alopal0014   alo     pal      4       0
#  25  alopal0011   alo     pal      4       0
#  26  alopal0015   alo     pal      4       0
#  27  alopal0013   alo     pal      4       0
#  28  alopal0012   alo     pal      4       0,
#  195:            Tip Genus Species  Clade  Branch
#  0   homsap2382   hom     sap    195       1
#  1   panpan0367   pan     pan    195       2
#  2   pansch0481   pan     sch    195       2
#  3   pansch0480   pan     sch    195       2
#  4   thegel0018   the     gel    195       0
#  5   cerasc0010   cer     asc    195       0
#  6   papcyn0577   pap     cyn    195       0
#  7   papcyn0579   pap     cyn    195       0
#  8   papcyn0578   pap     cyn    195       0
#  9   papcyn0585   pap     cyn    195       0
#  10  papcyn0582   pap     cyn    195       0
#  11  papcyn0580   pap     cyn    195       0
#  12  papcyn0583   pap     cyn    195       0
#  13  papcyn0584   pap     cyn    195       0
#  14  papcyn0581   pap     cyn    195       0
#  15  papham0013   pap     ham    195       0,
#  41:            Tip Genus Species  Clade  Branch
#  0   pantro0404   pan     tro     41       0
#  1   panpan0568   pan     pan     41       0
#  2   panpan0569   pan     pan     41       0
#  3   panpan0567   pan     pan     41       0
#  4   cerasc0016   cer     asc     41       0
#  5   pantro0405   pan     tro     41       0
#  6   homsap3602   hom     sap     41       1
#  7   homsap3600   hom     sap     41       1
#  8   homsap3601   hom     sap     41       1
#  9   homsap3603   hom     sap     41       1
#  10  homsap3604   hom     sap     41       1
#  11  alosen0025   alo     sen     41       0,
#  193:            Tip Genus Species  Clade  Branch
#  0   homsap0844   hom     sap    193       1
#  1   papcyn0345   pap     cyn    193       0
#  2   papcyn0346   pap     cyn    193       0
#  3   papcyn0351   pap     cyn    193       0
#  4   papcyn0344   pap     cyn    193       0
#  5   papcyn0343   pap     cyn    193       0
#  6   papcyn0347   pap     cyn    193       0
#  7   papcyn0348   pap     cyn    193       0
#  8   papcyn0350   pap     cyn    193       0
#  9   papcyn0352   pap     cyn    193       0
#  10  papcyn0349   pap     cyn    193       0
#  11  papham0007   pap     ham    193       0,
#  78:            Tip Genus Species  Clade  Branch
#  0   homsap2599   hom     sap     78       0
#  1   papcyn0594   pap     cyn     78       0
#  2   papcyn0600   pap     cyn     78       0
#  3   papcyn0599   pap     cyn     78       0
#  4   papcyn0595   pap     cyn     78       0
#  5   papcyn0596   pap     cyn     78       0
#  6   papcyn0601   pap     cyn     78       0
#  7   papcyn0598   pap     cyn     78       0
#  8   papcyn0597   pap     cyn     78       0
#  9   pansch0484   pan     sch     78       2
#  10  homsap2600   hom     sap     78       0,
#  97:            Tip Genus Species  Clade  Branch
#  0   pansch0709   pan     sch     97       0
#  1   panpan0560   pan     pan     97       0
#  2   pansch0706   pan     sch     97       0
#  3   pansch0708   pan     sch     97       0
#  4   pansch0707   pan     sch     97       0
#  5   panpan0557   pan     pan     97       0
#  6   panpan0558   pan     pan     97       0
#  7   panpan0559   pan     pan     97       0
#  8   homsap3457   hom     sap     97       0
#  9   pansch0705   pan     sch     97       0
#  10  pansch0704   pan     sch     97       0
#  11  panpan0556   pan     pan     97       0
#  12  pantro0400   pan     tro     97       0
#  13  pantro0399   pan     tro     97       0
#  14  homsap3456   hom     sap     97       0
#  15  gorgor0130   gor     gor     97       0
#  16  gorgor0131   gor     gor     97       0
#  17  gorgor0132   gor     gor     97       0
#  18  gorgor0129   gor     gor     97       0,
#  62:            Tip Genus Species  Clade  Branch
#  0   homsap1032   hom     sap     62       1
#  1   pantro0224   pan     tro     62       2
#  2   pantro0223   pan     tro     62       2
#  3   pansch0342   pan     sch     62       2
#  4   pansch0341   pan     sch     62       2
#  5   pansch0343   pan     sch     62       2
#  6   pansch0339   pan     sch     62       2
#  7   pansch0340   pan     sch     62       2
#  8   pansch0346   pan     sch     62       2
#  9   pansch0344   pan     sch     62       2
#  10  pansch0345   pan     sch     62       2
#  11  panpan0287   pan     pan     62       2
#  12  panpan0288   pan     pan     62       2
#  13  gorgor0082   gor     gor     62       0,
#  25:            Tip Genus Species  Clade  Branch
#  0   pantro0558   pan     tro     25       0
#  1   pantro0560   pan     tro     25       0
#  2   pantro0559   pan     tro     25       0
#  3   pantro0556   pan     tro     25       0
#  4   pantro0557   pan     tro     25       0
#  5   pansch0952   pan     sch     25       0
#  6   pansch0951   pan     sch     25       0
#  7   pansch0950   pan     sch     25       0
#  8   panpan0807   pan     pan     25       0
#  9   pansch0949   pan     sch     25       0
#  10  pansch0948   pan     sch     25       0
#  11  homsap4672   hom     sap     25       1,
#  12:           Tip Genus Species  Clade  Branch
#  0  papcyn0968   pap     cyn     12       0
#  1  papcyn0969   pap     cyn     12       0
#  2  homsap5086   hom     sap     12       0
#  3  homsap5085   hom     sap     12       0
#  4  homsap5084   hom     sap     12       0
#  5  pansch1058   pan     sch     12       2
#  6  homsap5083   hom     sap     12       0
#  7  alocar0031   alo     car     12       0,
#  43:            Tip Genus Species  Clade  Branch
#  0   pansch0233   pan     sch     43       0
#  1   pansch0232   pan     sch     43       0
#  2   panpan0214   pan     pan     43       0
#  3   pansch0234   pan     sch     43       0
#  4   pansch0235   pan     sch     43       0
#  5   pantro0156   pan     tro     43       0
#  6   pantro0157   pan     tro     43       0
#  7   pantro0152   pan     tro     43       0
#  8   pantro0155   pan     tro     43       0
#  9   pantro0153   pan     tro     43       0
#  10  pantro0154   pan     tro     43       0
#  11  papcyn0316   pap     cyn     43       0
#  12  homsap0774   hom     sap     43       1,
#  169:           Tip Genus Species  Clade  Branch
#  0  panpan0639   pan     pan    169       0
#  1  panpan0638   pan     pan    169       0
#  2  pansch0778   pan     sch    169       0
#  3  panpan0640   pan     pan    169       0
#  4  homsap3869   hom     sap    169       1
#  5  homsap3870   hom     sap    169       1
#  6  homsap3871   hom     sap    169       1,
#  27:            Tip Genus Species  Clade  Branch
#  0   gorgor0000   gor     gor     27       0
#  1   gorgor0001   gor     gor     27       0
#  2   gorgor0002   gor     gor     27       0
#  3   gorgor0003   gor     gor     27       0
#  4   homsap0063   hom     sap     27       0
#  5   panpan0017   pan     pan     27       2
#  6   pansch0022   pan     sch     27       2
#  7   pansch0023   pan     sch     27       2
#  8   pansch0024   pan     sch     27       2
#  9   homsap0061   hom     sap     27       0
#  10  homsap0060   hom     sap     27       0
#  11  homsap0062   hom     sap     27       0,
#  44:            Tip Genus Species  Clade  Branch
#  0   pansch0333   pan     sch     44       0
#  1   panpan0278   pan     pan     44       0
#  2   papcyn0477   pap     cyn     44       0
#  3   papcyn0471   pap     cyn     44       0
#  4   papcyn0474   pap     cyn     44       0
#  5   papcyn0479   pap     cyn     44       0
#  6   papcyn0475   pap     cyn     44       0
#  7   papcyn0476   pap     cyn     44       0
#  8   papcyn0470   pap     cyn     44       0
#  9   papcyn0478   pap     cyn     44       0
#  10  papcyn0473   pap     cyn     44       0
#  11  papcyn0480   pap     cyn     44       0
#  12  papcyn0472   pap     cyn     44       0
#  13  papcyn0481   pap     cyn     44       0
#  14  pantro0221   pan     tro     44       0
#  15  panpan0277   pan     pan     44       0
#  16  panpan0276   pan     pan     44       0
#  17  panpan0275   pan     pan     44       0
#  18  panpan0274   pan     pan     44       0
#  19  pantro0220   pan     tro     44       0
#  20  pansch0332   pan     sch     44       0
#  21  panpan0273   pan     pan     44       0
#  22  pansch0330   pan     sch     44       0
#  23  pansch0329   pan     sch     44       0
#  24  pansch0331   pan     sch     44       0
#  25  homsap1028   hom     sap     44       1,
#  198:           Tip Genus Species  Clade  Branch
#  0  homsap0483   hom     sap    198       0
#  1  homsap0482   hom     sap    198       0
#  2  alosen0013   alo     sen    198       0
#  3  alopig0040   alo     pig    198       0
#  4  alopig0039   alo     pig    198       0
#  5  alopig0038   alo     pig    198       0
#  6  alopig0037   alo     pig    198       0
#  7  alopal0023   alo     pal    198       0
#  8  alopal0024   alo     pal    198       0,
#  124:           Tip Genus Species  Clade  Branch
#  0  panpan0609   pan     pan    124       0
#  1  homsap3803   hom     sap    124       0
#  2  homsap3802   hom     sap    124       0
#  3  homsap3805   hom     sap    124       0
#  4  homsap3804   hom     sap    124       0
#  5  gorgor0134   gor     gor    124       0
#  6  pansch0747   pan     sch    124       0
#  7  pansch0746   pan     sch    124       0
#  8  colgue0008   col     gue    124       0,
#  48:           Tip Genus Species  Clade  Branch
#  0  homsap0465   hom     sap     48       0
#  1  homsap0463   hom     sap     48       0
#  2  homsap0464   hom     sap     48       0
#  3  prover0010   pro     ver     48       0
#  4  prover0008   pro     ver     48       0
#  5  prover0009   pro     ver     48       0
#  6  prover0007   pro     ver     48       0
#  7  prover0006   pro     ver     48       0
#  8  homsap0466   hom     sap     48       0
#  9  lemcat0001   lem     cat     48       0,
#  29:            Tip Genus Species  Clade  Branch
#  0   homsap1001   hom     sap     29       0
#  1   papcyn0443   pap     cyn     29       0
#  2   papcyn0442   pap     cyn     29       0
#  3   papcyn0444   pap     cyn     29       0
#  4   papcyn0440   pap     cyn     29       0
#  5   papcyn0439   pap     cyn     29       0
#  6   papcyn0445   pap     cyn     29       0
#  7   papcyn0441   pap     cyn     29       0
#  8   papcyn0451   pap     cyn     29       0
#  9   papcyn0450   pap     cyn     29       0
#  10  papcyn0449   pap     cyn     29       0
#  11  papcyn0447   pap     cyn     29       0
#  12  papcyn0446   pap     cyn     29       0
#  13  papcyn0448   pap     cyn     29       0
#  14  papcyn0438   pap     cyn     29       0
#  15  panpan0264   pan     pan     29       0
#  16  papcyn0437   pap     cyn     29       0
#  17  homsap0998   hom     sap     29       0
#  18  pansch0314   pan     sch     29       0
#  19  pansch0315   pan     sch     29       0
#  20  pansch0317   pan     sch     29       0
#  21  pansch0316   pan     sch     29       0
#  22  pantro0206   pan     tro     29       0
#  23  pantro0205   pan     tro     29       0
#  24  pantro0204   pan     tro     29       0
#  25  pantro0207   pan     tro     29       0
#  26  homsap0999   hom     sap     29       0
#  27  homsap1000   hom     sap     29       0,
#  49:            Tip Genus Species  Clade  Branch
#  0   cebcap0070   ceb     cap     49       0
#  1   cebcap0071   ceb     cap     49       0
#  2   cebcap0073   ceb     cap     49       0
#  3   cebcap0072   ceb     cap     49       0
#  4   cebcap0068   ceb     cap     49       0
#  5   cebcap0064   ceb     cap     49       0
#  6   cebcap0066   ceb     cap     49       0
#  7   cebcap0065   ceb     cap     49       0
#  8   cebcap0067   ceb     cap     49       0
#  9   cebcap0069   ceb     cap     49       0
#  10  cebcap0062   ceb     cap     49       0
#  11  cebcap0063   ceb     cap     49       0
#  12  homsap2915   hom     sap     49       0
#  13  pansch0641   pan     sch     49       2
#  14  homsap2912   hom     sap     49       0
#  15  homsap2913   hom     sap     49       0
#  16  homsap2914   hom     sap     49       0,
#  2:            Tip Genus Species  Clade  Branch
#  0   panpan0461   pan     pan      2       0
#  1   panpan0462   pan     pan      2       0
#  2   pantro0332   pan     tro      2       0
#  3   pantro0331   pan     tro      2       0
#  4   papcyn0635   pap     cyn      2       0
#  5   papcyn0633   pap     cyn      2       0
#  6   papcyn0639   pap     cyn      2       0
#  7   papcyn0636   pap     cyn      2       0
#  8   papcyn0634   pap     cyn      2       0
#  9   papcyn0637   pap     cyn      2       0
#  10  papcyn0638   pap     cyn      2       0
#  11  homsap2844   hom     sap      2       1,
#  142:            Tip Genus Species  Clade  Branch
#  0   panpan0197   pan     pan    142       0
#  1   panpan0196   pan     pan    142       0
#  2   panpan0198   pan     pan    142       0
#  3   panpan0195   pan     pan    142       0
#  4   panpan0193   pan     pan    142       0
#  5   panpan0194   pan     pan    142       0
#  6   panpan0191   pan     pan    142       0
#  7   panpan0192   pan     pan    142       0
#  8   pantro0135   pan     tro    142       0
#  9   pantro0137   pan     tro    142       0
#  10  pantro0136   pan     tro    142       0
#  11  pantro0134   pan     tro    142       0
#  12  pantro0133   pan     tro    142       0
#  13  pantro0132   pan     tro    142       0
#  14  pansch0200   pan     sch    142       0
#  15  pansch0199   pan     sch    142       0
#  16  pansch0201   pan     sch    142       0
#  17  pansch0198   pan     sch    142       0
#  18  pansch0202   pan     sch    142       0
#  19  pansch0203   pan     sch    142       0
#  20  pansch0204   pan     sch    142       0
#  21  pansch0205   pan     sch    142       0
#  22  pansch0196   pan     sch    142       0
#  23  pansch0197   pan     sch    142       0
#  24  panpan0190   pan     pan    142       0
#  25  papcyn0263   pap     cyn    142       0
#  26  papcyn0264   pap     cyn    142       0
#  27  papcyn0265   pap     cyn    142       0
#  28  papcyn0259   pap     cyn    142       0
#  29  papcyn0260   pap     cyn    142       0
#  30  papcyn0261   pap     cyn    142       0
#  31  papcyn0262   pap     cyn    142       0
#  32  papcyn0267   pap     cyn    142       0
#  33  papcyn0266   pap     cyn    142       0
#  34  papcyn0272   pap     cyn    142       0
#  35  papcyn0268   pap     cyn    142       0
#  36  papcyn0271   pap     cyn    142       0
#  37  papcyn0270   pap     cyn    142       0
#  38  papcyn0269   pap     cyn    142       0
#  39  homsap0519   hom     sap    142       1,
#  174:            Tip Genus Species  Clade  Branch
#  0   pantro0383   pan     tro    174       0
#  1   pantro0384   pan     tro    174       0
#  2   pansch0673   pan     sch    174       0
#  3   pansch0669   pan     sch    174       0
#  4   pansch0672   pan     sch    174       0
#  5   pansch0679   pan     sch    174       0
#  6   pansch0678   pan     sch    174       0
#  7   pansch0677   pan     sch    174       0
#  8   pansch0671   pan     sch    174       0
#  9   panpan0541   pan     pan    174       0
#  10  pansch0670   pan     sch    174       0
#  11  pansch0676   pan     sch    174       0
#  12  pansch0675   pan     sch    174       0
#  13  pansch0674   pan     sch    174       0
#  14  homsap3373   hom     sap    174       1
#  15  homsap3374   hom     sap    174       1
#  16  homsap3372   hom     sap    174       1
#  17  homsap3375   hom     sap    174       1
#  18  homsap3376   hom     sap    174       1,
#  31:            Tip Genus Species  Clade  Branch
#  0   homsap0159   hom     sap     31       0
#  1   homsap0158   hom     sap     31       0
#  2   pansch0053   pan     sch     31       0
#  3   homsap0160   hom     sap     31       0
#  4   pansch0054   pan     sch     31       0
#  5   homsap0161   hom     sap     31       0
#  6   alosen0002   alo     sen     31       0
#  7   homsap0162   hom     sap     31       0
#  8   alosen0001   alo     sen     31       0
#  9   alosen0000   alo     sen     31       0
#  10  alopal0003   alo     pal     31       0
#  11  alopal0000   alo     pal     31       0
#  12  alopal0002   alo     pal     31       0
#  13  alopal0004   alo     pal     31       0
#  14  alopal0001   alo     pal     31       0
#  15  alopal0005   alo     pal     31       0,
#  128:           Tip Genus Species  Clade  Branch
#  0  panpan0202   pan     pan    128       0
#  1  panpan0203   pan     pan    128       0
#  2  panpan0201   pan     pan    128       0
#  3  pantro0141   pan     tro    128       0
#  4  pansch0215   pan     sch    128       0
#  5  pansch0213   pan     sch    128       0
#  6  pansch0214   pan     sch    128       0
#  7  homsap0637   hom     sap    128       1,
#  190:           Tip Genus Species  Clade  Branch
#  0  homsap0152   hom     sap    190       1
#  1  panpan0046   pan     pan    190       2
#  2  panpan0045   pan     pan    190       2
#  3  panpan0044   pan     pan    190       2
#  4  pansch0052   pan     sch    190       2
#  5  papcyn0029   pap     cyn    190       0
#  6  papcyn0031   pap     cyn    190       0
#  7  papcyn0030   pap     cyn    190       0
#  8  papcyn0028   pap     cyn    190       0,
#  131:           Tip Genus Species  Clade  Branch
#  0  panpan0372   pan     pan    131       0
#  1  panpan0370   pan     pan    131       0
#  2  panpan0371   pan     pan    131       0
#  3  panpan0373   pan     pan    131       0
#  4  panpan0374   pan     pan    131       0
#  5  pantro0271   pan     tro    131       0
#  6  homsap2538   hom     sap    131       1,
#  129:            Tip Genus Species  Clade  Branch
#  0   homsap0293   hom     sap    129       1
#  1   panpan0102   pan     pan    129       2
#  2   panpan0101   pan     pan    129       2
#  3   panpan0105   pan     pan    129       2
#  4   panpan0104   pan     pan    129       2
#  5   panpan0103   pan     pan    129       2
#  6   pantro0036   pan     tro    129       2
#  7   pansch0094   pan     sch    129       2
#  8   pansch0091   pan     sch    129       2
#  9   pansch0093   pan     sch    129       2
#  10  pansch0090   pan     sch    129       2
#  11  pansch0089   pan     sch    129       2
#  12  panpan0100   pan     pan    129       2
#  13  pansch0092   pan     sch    129       2
#  14  prover0003   pro     ver    129       0
#  15  prover0000   pro     ver    129       0
#  16  prover0001   pro     ver    129       0
#  17  prover0002   pro     ver    129       0
#  18  atehyb0000   ate     hyb    129       0
#  19  alopal0011   alo     pal    129       0
#  20  alosen0008   alo     sen    129       0
#  21  alopig0012   alo     pig    129       0
#  22  alopig0013   alo     pig    129       0
#  23  alopal0014   alo     pal    129       0
#  24  alopal0015   alo     pal    129       0
#  25  alopal0013   alo     pal    129       0
#  26  alopal0012   alo     pal    129       0,
#  176:            Tip Genus Species  Clade  Branch
#  0   pantro0385   pan     tro    176       0
#  1   panpan0542   pan     pan    176       0
#  2   panpan0543   pan     pan    176       0
#  3   pansch0685   pan     sch    176       0
#  4   pansch0687   pan     sch    176       0
#  5   pansch0686   pan     sch    176       0
#  6   pansch0681   pan     sch    176       0
#  7   pansch0682   pan     sch    176       0
#  8   pansch0684   pan     sch    176       0
#  9   pansch0683   pan     sch    176       0
#  10  homsap3400   hom     sap    176       1
#  11  homsap3403   hom     sap    176       1
#  12  homsap3401   hom     sap    176       1
#  13  homsap3402   hom     sap    176       1,
#  32:           Tip Genus Species  Clade  Branch
#  0  panpan0168   pan     pan     32       0
#  1  pantro0111   pan     tro     32       0
#  2  pantro0112   pan     tro     32       0
#  3  pantro0113   pan     tro     32       0
#  4  pansch0170   pan     sch     32       0
#  5  pansch0169   pan     sch     32       0
#  6  homsap0478   hom     sap     32       1,
#  33:            Tip Genus Species  Clade  Branch
#  0   panpan0581   pan     pan     33       0
#  1   homsap3690   hom     sap     33       1
#  2   panpan0580   pan     pan     33       0
#  3   panpan0578   pan     pan     33       0
#  4   panpan0577   pan     pan     33       0
#  5   panpan0576   pan     pan     33       0
#  6   panpan0579   pan     pan     33       0
#  7   pantro0412   pan     tro     33       0
#  8   pantro0408   pan     tro     33       0
#  9   pantro0410   pan     tro     33       0
#  10  pantro0411   pan     tro     33       0
#  11  pantro0409   pan     tro     33       0
#  12  pansch0721   pan     sch     33       0
#  13  pansch0725   pan     sch     33       0
#  14  pansch0722   pan     sch     33       0
#  15  pansch0724   pan     sch     33       0
#  16  pansch0726   pan     sch     33       0
#  17  pansch0723   pan     sch     33       0
#  18  pantro0407   pan     tro     33       0,
#  216:           Tip Genus Species  Clade  Branch
#  0  papcyn0928   pap     cyn    216       0
#  1  papcyn0927   pap     cyn    216       0
#  2  papcyn0932   pap     cyn    216       0
#  3  papcyn0931   pap     cyn    216       0
#  4  papcyn0930   pap     cyn    216       0
#  5  papcyn0929   pap     cyn    216       0
#  6  pansch1022   pan     sch    216       2
#  7  homsap4892   hom     sap    216       1,
#  179:            Tip Genus Species  Clade  Branch
#  0   gorgor0156   gor     gor    179       0
#  1   gorgor0161   gor     gor    179       0
#  2   gorgor0162   gor     gor    179       0
#  3   gorgor0158   gor     gor    179       0
#  4   gorgor0159   gor     gor    179       0
#  5   gorgor0160   gor     gor    179       0
#  6   gorgor0157   gor     gor    179       0
#  7   panpan0807   pan     pan    179       2
#  8   pansch0952   pan     sch    179       2
#  9   pansch0950   pan     sch    179       2
#  10  pansch0951   pan     sch    179       2
#  11  pansch0949   pan     sch    179       2
#  12  pansch0948   pan     sch    179       2
#  13  pantro0559   pan     tro    179       2
#  14  pantro0560   pan     tro    179       2
#  15  pantro0558   pan     tro    179       2
#  16  pantro0556   pan     tro    179       2
#  17  pantro0557   pan     tro    179       2
#  18  homsap4672   hom     sap    179       1,
#  55:            Tip Genus Species  Clade  Branch
#  0   homsap2617   hom     sap     55       0
#  1   panpan0387   pan     pan     55       0
#  2   homsap2612   hom     sap     55       0
#  3   homsap2611   hom     sap     55       0
#  4   homsap2613   hom     sap     55       0
#  5   homsap2614   hom     sap     55       0
#  6   panpan0388   pan     pan     55       0
#  7   panpan0389   pan     pan     55       0
#  8   homsap2616   hom     sap     55       0
#  9   homsap2615   hom     sap     55       0
#  10  prover0044   pro     ver     55       0,
#  72:            Tip Genus Species  Clade  Branch
#  0   pantro0241   pan     tro     72       2
#  1   panpan0310   pan     pan     72       2
#  2   papcyn0493   pap     cyn     72       0
#  3   papcyn0491   pap     cyn     72       0
#  4   papcyn0489   pap     cyn     72       0
#  5   papcyn0492   pap     cyn     72       0
#  6   papcyn0490   pap     cyn     72       0
#  7   papcyn0497   pap     cyn     72       0
#  8   papcyn0496   pap     cyn     72       0
#  9   papcyn0495   pap     cyn     72       0
#  10  papcyn0494   pap     cyn     72       0
#  11  homsap1380   hom     sap     72       1
#  12  homsap1381   hom     sap     72       1,
#  3:            Tip Genus Species  Clade  Branch
#  0   papcyn0532   pap     cyn      3       0
#  1   papcyn0533   pap     cyn      3       0
#  2   pansch0446   pan     sch      3       2
#  3   pansch0447   pan     sch      3       2
#  4   pansch0445   pan     sch      3       2
#  5   pantro0261   pan     tro      3       2
#  6   pansch0443   pan     sch      3       2
#  7   pansch0444   pan     sch      3       2
#  8   panpan0349   pan     pan      3       2
#  9   panpan0350   pan     pan      3       2
#  10  homsap1914   hom     sap      3       1
#  11  homsap1915   hom     sap      3       1,
#  140:            Tip Genus Species  Clade  Branch
#  0   homsap0851   hom     sap    140       0
#  1   homsap0852   hom     sap    140       0
#  2   panpan0241   pan     pan    140       2
#  3   panpan0240   pan     pan    140       2
#  4   panpan0239   pan     pan    140       2
#  5   panpan0244   pan     pan    140       2
#  6   panpan0243   pan     pan    140       2
#  7   panpan0242   pan     pan    140       2
#  8   pansch0281   pan     sch    140       2
#  9   pansch0280   pan     sch    140       2
#  10  pansch0284   pan     sch    140       2
#  11  pansch0283   pan     sch    140       2
#  12  pansch0287   pan     sch    140       2
#  13  pansch0286   pan     sch    140       2
#  14  pansch0288   pan     sch    140       2
#  15  pansch0285   pan     sch    140       2
#  16  pansch0282   pan     sch    140       2
#  17  pansch0279   pan     sch    140       2
#  18  pansch0278   pan     sch    140       2
#  19  panpan0238   pan     pan    140       2
#  20  pansch0289   pan     sch    140       2
#  21  pantro0183   pan     tro    140       2
#  22  pantro0182   pan     tro    140       2
#  23  pantro0181   pan     tro    140       2
#  24  pantro0180   pan     tro    140       2
#  25  pantro0179   pan     tro    140       2
#  26  homsap0853   hom     sap    140       0,
#  74:            Tip Genus Species  Clade  Branch
#  0   homsap0460   hom     sap     74       1
#  1   homsap0458   hom     sap     74       1
#  2   homsap0459   hom     sap     74       1
#  3   pansch0154   pan     sch     74       2
#  4   pansch0157   pan     sch     74       2
#  5   pansch0153   pan     sch     74       2
#  6   pansch0156   pan     sch     74       2
#  7   panpan0159   pan     pan     74       2
#  8   pansch0159   pan     sch     74       2
#  9   pansch0155   pan     sch     74       2
#  10  pansch0158   pan     sch     74       2
#  11  pantro0101   pan     tro     74       2
#  12  panpan0161   pan     pan     74       2
#  13  panpan0162   pan     pan     74       2
#  14  panpan0160   pan     pan     74       2
#  15  thegel0004   the     gel     74       0,
#  202:            Tip Genus Species  Clade  Branch
#  0   papcyn0944   pap     cyn    202       0
#  1   papcyn0946   pap     cyn    202       0
#  2   papcyn0945   pap     cyn    202       0
#  3   papcyn0947   pap     cyn    202       0
#  4   papcyn0943   pap     cyn    202       0
#  5   panpan0892   pan     pan    202       0
#  6   panpan0891   pan     pan    202       0
#  7   homsap5007   hom     sap    202       0
#  8   pansch1040   pan     sch    202       0
#  9   panpan0894   pan     pan    202       0
#  10  pansch1039   pan     sch    202       0
#  11  panpan0893   pan     pan    202       0
#  12  homsap5008   hom     sap    202       0,
#  103:            Tip Genus Species  Clade  Branch
#  0   panpan0103   pan     pan    103       0
#  1   panpan0104   pan     pan    103       0
#  2   panpan0105   pan     pan    103       0
#  3   panpan0101   pan     pan    103       0
#  4   panpan0102   pan     pan    103       0
#  5   pansch0093   pan     sch    103       0
#  6   pansch0091   pan     sch    103       0
#  7   pansch0092   pan     sch    103       0
#  8   panpan0100   pan     pan    103       0
#  9   pansch0094   pan     sch    103       0
#  10  pansch0089   pan     sch    103       0
#  11  pansch0090   pan     sch    103       0
#  12  pantro0036   pan     tro    103       0
#  13  homsap0293   hom     sap    103       1,
#  59:            Tip Genus Species  Clade  Branch
#  0   homsap2842   hom     sap     59       0
#  1   homsap2841   hom     sap     59       0
#  2   homsap2840   hom     sap     59       0
#  3   homsap2838   hom     sap     59       0
#  4   homsap2839   hom     sap     59       0
#  5   homsap2843   hom     sap     59       0
#  6   pansch0549   pan     sch     59       2
#  7   pansch0551   pan     sch     59       2
#  8   pansch0554   pan     sch     59       2
#  9   pansch0553   pan     sch     59       2
#  10  pansch0552   pan     sch     59       2
#  11  pansch0550   pan     sch     59       2
#  12  panpan0455   pan     pan     59       2
#  13  panpan0454   pan     pan     59       2
#  14  pantro0327   pan     tro     59       2
#  15  pantro0326   pan     tro     59       2
#  16  pantro0325   pan     tro     59       2,
#  181:            Tip Genus Species  Clade  Branch
#  0   pantro0260   pan     tro    181       0
#  1   pansch0437   pan     sch    181       0
#  2   pansch0439   pan     sch    181       0
#  3   pansch0440   pan     sch    181       0
#  4   pansch0441   pan     sch    181       0
#  5   pansch0442   pan     sch    181       0
#  6   pansch0438   pan     sch    181       0
#  7   panpan0345   pan     pan    181       0
#  8   panpan0348   pan     pan    181       0
#  9   panpan0346   pan     pan    181       0
#  10  panpan0347   pan     pan    181       0
#  11  homsap1887   hom     sap    181       1,
#  6:            Tip Genus Species  Clade  Branch
#  0   homsap4237   hom     sap      6       0
#  1   panpan0731   pan     pan      6       0
#  2   homsap4233   hom     sap      6       0
#  3   panpan0728   pan     pan      6       0
#  4   panpan0729   pan     pan      6       0
# ...
#  26  panpan0244   pan     pan    136       2
#  27  homsap0854   hom     sap    136       0,
#  130:           Tip Genus Species  Clade  Branch
#  0  pansch0349   pan     sch    130       0
#  1  panpan0289   pan     pan    130       0
#  2  pantro0226   pan     tro    130       0
#  3  pantro0227   pan     tro    130       0
#  4  pantro0230   pan     tro    130       0
#  5  pantro0229   pan     tro    130       0
#  6  pantro0228   pan     tro    130       0
#  7  homsap1057   hom     sap    130       1,
#  171:            Tip Genus Species  Clade  Branch
#  0   panpan0780   pan     pan    171       2
#  1   panpan0781   pan     pan    171       2
#  2   homsap4520   hom     sap    171       1
#  3   papcyn0831   pap     cyn    171       0
#  4   papcyn0827   pap     cyn    171       0
#  5   papcyn0829   pap     cyn    171       0
#  6   papcyn0825   pap     cyn    171       0
#  7   papcyn0828   pap     cyn    171       0
#  8   papcyn0830   pap     cyn    171       0
#  9   papcyn0822   pap     cyn    171       0
#  10  papcyn0823   pap     cyn    171       0
#  11  papcyn0824   pap     cyn    171       0
#  12  papcyn0826   pap     cyn    171       0
#  13  papcyn0821   pap     cyn    171       0,
#  57:            Tip Genus Species  Clade  Branch
#  0   homsap2786   hom     sap     57       0
#  1   pansch0525   pan     sch     57       0
#  2   pansch0528   pan     sch     57       0
#  3   pansch0527   pan     sch     57       0
#  4   pansch0526   pan     sch     57       0
#  5   pansch0529   pan     sch     57       0
#  6   pansch0530   pan     sch     57       0
#  7   pansch0533   pan     sch     57       0
#  8   pansch0532   pan     sch     57       0
#  9   pansch0523   pan     sch     57       0
#  10  pansch0524   pan     sch     57       0
#  11  pansch0531   pan     sch     57       0
#  12  pantro0310   pan     tro     57       0
#  13  pantro0309   pan     tro     57       0
#  14  pantro0311   pan     tro     57       0
#  15  pantro0312   pan     tro     57       0
#  16  pantro0313   pan     tro     57       0
#  17  pantro0314   pan     tro     57       0
#  18  panpan0435   pan     pan     57       0
#  19  panpan0437   pan     pan     57       0
#  20  panpan0436   pan     pan     57       0
#  21  panpan0432   pan     pan     57       0
#  22  panpan0433   pan     pan     57       0
#  23  panpan0431   pan     pan     57       0
#  24  panpan0434   pan     pan     57       0
#  25  homsap2785   hom     sap     57       0
#  26  atebel0013   ate     bel     57       0,
#  153:            Tip Genus Species  Clade  Branch
#  0   pantro0357   pan     tro    153       0
#  1   pantro0356   pan     tro    153       0
#  2   panpan0497   pan     pan    153       0
#  3   panpan0495   pan     pan    153       0
#  4   panpan0496   pan     pan    153       0
#  5   panpan0493   pan     pan    153       0
#  6   panpan0492   pan     pan    153       0
#  7   panpan0491   pan     pan    153       0
#  8   panpan0490   pan     pan    153       0
#  9   panpan0494   pan     pan    153       0
#  10  homsap2860   hom     sap    153       1,
#  76:            Tip Genus Species  Clade  Branch
#  0   homsap1509   hom     sap     76       0
#  1   homsap1508   hom     sap     76       0
#  2   homsap1506   hom     sap     76       0
#  3   homsap1505   hom     sap     76       0
#  4   homsap1507   hom     sap     76       0
#  5   homsap1510   hom     sap     76       0
#  6   homsap1511   hom     sap     76       0
#  7   gorgor0095   gor     gor     76       0
#  8   gorgor0096   gor     gor     76       0
#  9   gorgor0097   gor     gor     76       0
#  10  pansch0397   pan     sch     76       2
#  11  pansch0395   pan     sch     76       2
#  12  pansch0396   pan     sch     76       2
#  13  panpan0323   pan     pan     76       2
#  14  pantro0246   pan     tro     76       2
#  15  pansch0399   pan     sch     76       2
#  16  pansch0398   pan     sch     76       2
#  17  pansch0400   pan     sch     76       2
#  18  pantro0247   pan     tro     76       2,
#  53:           Tip Genus Species  Clade  Branch
#  0  homsap0501   hom     sap     53       0
#  1  homsap0500   hom     sap     53       0
#  2  atehyb0012   ate     hyb     53       0
#  3  atebel0008   ate     bel     53       0
#  4  atebel0009   ate     bel     53       0
#  5  laglag0026   lag     lag     53       0
#  6  alopig0050   alo     pig     53       0,
#  99:            Tip Genus Species  Clade  Branch
#  0   pansch0552   pan     sch     99       0
#  1   pansch0549   pan     sch     99       0
#  2   panpan0454   pan     pan     99       0
#  3   panpan0455   pan     pan     99       0
#  4   pantro0326   pan     tro     99       0
#  5   pantro0327   pan     tro     99       0
#  6   pansch0550   pan     sch     99       0
#  7   pansch0551   pan     sch     99       0
#  8   pansch0554   pan     sch     99       0
#  9   pansch0553   pan     sch     99       0
#  10  homsap2843   hom     sap     99       1
#  11  pantro0325   pan     tro     99       0,
#  123:           Tip Genus Species  Clade  Branch
#  0  papcyn0594   pap     cyn    123       0
#  1  papcyn0600   pap     cyn    123       0
#  2  papcyn0595   pap     cyn    123       0
#  3  papcyn0599   pap     cyn    123       0
#  4  papcyn0597   pap     cyn    123       0
#  5  papcyn0596   pap     cyn    123       0
#  6  papcyn0601   pap     cyn    123       0
#  7  papcyn0598   pap     cyn    123       0
#  8  pansch0484   pan     sch    123       2
#  9  homsap2600   hom     sap    123       1,
#  213:            Tip Genus Species  Clade  Branch
#  0   homsap2849   hom     sap    213       0
#  1   homsap2848   hom     sap    213       0
#  2   papcyn0655   pap     cyn    213       0
#  3   papcyn0650   pap     cyn    213       0
#  4   papcyn0652   pap     cyn    213       0
#  5   papcyn0651   pap     cyn    213       0
#  6   papcyn0656   pap     cyn    213       0
#  7   papcyn0654   pap     cyn    213       0
#  8   papcyn0653   pap     cyn    213       0
#  9   papcyn0649   pap     cyn    213       0
#  10  papham0019   pap     ham    213       0,
#  36:            Tip Genus Species  Clade  Branch
#  0   homsap2812   hom     sap     36       1
#  1   homsap2813   hom     sap     36       1
#  2   homsap2814   hom     sap     36       1
#  3   homsap2811   hom     sap     36       1
#  4   homsap2817   hom     sap     36       1
#  5   homsap2810   hom     sap     36       1
#  6   homsap2809   hom     sap     36       1
#  7   homsap2816   hom     sap     36       1
#  8   homsap2815   hom     sap     36       1
#  9   papham0016   pap     ham     36       0
#  10  papanu0003   pap     anu     36       0,
#  146:            Tip Genus Species  Clade  Branch
#  0   prover0019   pro     ver    146       0
#  1   prover0018   pro     ver    146       0
#  2   prover0017   pro     ver    146       0
#  3   prover0016   pro     ver    146       0
#  4   homsap0483   hom     sap    146       1
#  5   homsap0482   hom     sap    146       1
#  6   alosen0013   alo     sen    146       0
#  7   alopig0039   alo     pig    146       0
#  8   alopig0040   alo     pig    146       0
#  9   alopig0038   alo     pig    146       0
#  10  alopig0037   alo     pig    146       0
#  11  alopal0023   alo     pal    146       0
#  12  alopal0024   alo     pal    146       0,
#  90:            Tip Genus Species  Clade  Branch
#  0   panpan0277   pan     pan     90       0
#  1   panpan0276   pan     pan     90       0
#  2   panpan0274   pan     pan     90       0
#  3   panpan0275   pan     pan     90       0
#  4   pantro0221   pan     tro     90       0
#  5   pansch0329   pan     sch     90       0
#  6   pansch0330   pan     sch     90       0
#  7   panpan0273   pan     pan     90       0
#  8   pansch0332   pan     sch     90       0
#  9   pansch0331   pan     sch     90       0
#  10  pantro0220   pan     tro     90       0
#  11  homsap1028   hom     sap     90       1,
#  177:            Tip Genus Species  Clade  Branch
#  0   homsap4806   hom     sap    177       0
#  1   homsap4804   hom     sap    177       0
#  2   homsap4803   hom     sap    177       0
#  3   homsap4805   hom     sap    177       0
#  4   pantro0576   pan     tro    177       0
#  5   pantro0575   pan     tro    177       0
#  6   pantro0577   pan     tro    177       0
#  7   gorgor0163   gor     gor    177       0
#  8   gorgor0164   gor     gor    177       0
#  9   panpan0833   pan     pan    177       0
#  10  panpan0834   pan     pan    177       0
#  11  panpan0832   pan     pan    177       0
#  12  panpan0831   pan     pan    177       0
#  13  panpan0830   pan     pan    177       0
#  14  homsap4807   hom     sap    177       0
#  15  alopig0082   alo     pig    177       0,
#  61:            Tip Genus Species  Clade  Branch
#  0   pansch0871   pan     sch     61       0
#  1   panpan0725   pan     pan     61       0
#  2   panpan0724   pan     pan     61       0
#  3   panpan0726   pan     pan     61       0
#  4   homsap4200   hom     sap     61       0
#  5   panpan0727   pan     pan     61       0
#  6   homsap4202   hom     sap     61       0
#  7   homsap4201   hom     sap     61       0
#  8   pansch0869   pan     sch     61       0
#  9   pansch0870   pan     sch     61       0
#  10  alocar0021   alo     car     61       0,
#  77:           Tip Genus Species  Clade  Branch
#  0  homsap4942   hom     sap     77       1
#  1  pantro0604   pan     tro     77       0
#  2  panpan0884   pan     pan     77       0
#  3  pantro0603   pan     tro     77       0
#  4  pantro0601   pan     tro     77       0
#  5  pantro0600   pan     tro     77       0
#  6  pantro0602   pan     tro     77       0,
#  105:            Tip Genus Species  Clade  Branch
#  0   panpan0155   pan     pan    105       0
#  1   panpan0154   pan     pan    105       0
#  2   panpan0153   pan     pan    105       0
#  3   panpan0152   pan     pan    105       0
#  4   panpan0149   pan     pan    105       0
#  5   panpan0148   pan     pan    105       0
#  6   panpan0151   pan     pan    105       0
#  7   panpan0150   pan     pan    105       0
#  8   pansch0146   pan     sch    105       0
#  9   pansch0147   pan     sch    105       0
#  10  panpan0147   pan     pan    105       0
#  11  pansch0145   pan     sch    105       0
#  12  pansch0143   pan     sch    105       0
#  13  pansch0144   pan     sch    105       0
#  14  pantro0089   pan     tro    105       0
#  15  pantro0087   pan     tro    105       0
#  16  pantro0088   pan     tro    105       0
#  17  pantro0093   pan     tro    105       0
#  18  pantro0090   pan     tro    105       0
#  19  pantro0091   pan     tro    105       0
#  20  pantro0092   pan     tro    105       0
#  21  papcyn0213   pap     cyn    105       0
#  22  papcyn0215   pap     cyn    105       0
#  23  papcyn0212   pap     cyn    105       0
#  24  papcyn0216   pap     cyn    105       0
#  25  papcyn0214   pap     cyn    105       0
#  26  homsap0387   hom     sap    105       1,
#  197:           Tip Genus Species  Clade  Branch
#  0  panpan0380   pan     pan    197       2
#  1  pantro0274   pan     tro    197       2
#  2  pantro0275   pan     tro    197       2
#  3  pantro0273   pan     tro    197       2
#  4  homsap2570   hom     sap    197       1
#  5  alosen0022   alo     sen    197       0
#  6  alopig0057   alo     pig    197       0
#  7  alopig0058   alo     pig    197       0,
#  54:            Tip Genus Species  Clade  Branch
#  0   homsap3937   hom     sap     54       0
#  1   homsap3936   hom     sap     54       0
#  2   homsap3935   hom     sap     54       0
#  3   pantro0459   pan     tro     54       0
#  4   pantro0458   pan     tro     54       0
#  5   pantro0457   pan     tro     54       0
#  6   panpan0659   pan     pan     54       0
#  7   homsap3934   hom     sap     54       0
#  8   papcyn0768   pap     cyn     54       0
#  9   homsap3933   hom     sap     54       0
#  10  alopig0074   alo     pig     54       0,
#  85:            Tip Genus Species  Clade  Branch
#  0   panpan0160   pan     pan     85       0
#  1   panpan0162   pan     pan     85       0
#  2   panpan0161   pan     pan     85       0
#  3   pantro0101   pan     tro     85       0
#  4   pansch0158   pan     sch     85       0
#  5   pansch0159   pan     sch     85       0
#  6   panpan0159   pan     pan     85       0
#  7   pansch0155   pan     sch     85       0
#  8   pansch0154   pan     sch     85       0
#  9   pansch0157   pan     sch     85       0
#  10  pansch0156   pan     sch     85       0
#  11  pansch0153   pan     sch     85       0
#  12  homsap0460   hom     sap     85       1
#  13  homsap0459   hom     sap     85       1
#  14  homsap0458   hom     sap     85       1,
#  137:            Tip Genus Species  Clade  Branch
#  0   panpan0435   pan     pan    137       0
#  1   panpan0437   pan     pan    137       0
#  2   panpan0436   pan     pan    137       0
#  3   panpan0431   pan     pan    137       0
#  4   panpan0433   pan     pan    137       0
#  5   panpan0432   pan     pan    137       0
#  6   panpan0434   pan     pan    137       0
#  7   pansch0523   pan     sch    137       0
#  8   pansch0524   pan     sch    137       0
#  9   pansch0532   pan     sch    137       0
#  10  pansch0530   pan     sch    137       0
#  11  pansch0528   pan     sch    137       0
#  12  pansch0531   pan     sch    137       0
#  13  pansch0527   pan     sch    137       0
#  14  pansch0525   pan     sch    137       0
#  15  pansch0526   pan     sch    137       0
#  16  pansch0529   pan     sch    137       0
#  17  pansch0533   pan     sch    137       0
#  18  pantro0313   pan     tro    137       0
#  19  pantro0314   pan     tro    137       0
#  20  pantro0311   pan     tro    137       0
#  21  pantro0312   pan     tro    137       0
#  22  pantro0309   pan     tro    137       0
#  23  pantro0310   pan     tro    137       0
#  24  homsap2786   hom     sap    137       1,
#  125:            Tip Genus Species  Clade  Branch
#  0   papcyn0306   pap     cyn    125       0
#  1   papcyn0286   pap     cyn    125       0
#  2   papcyn0291   pap     cyn    125       0
#  3   papcyn0299   pap     cyn    125       0
#  4   papcyn0290   pap     cyn    125       0
#  5   papcyn0289   pap     cyn    125       0
#  6   papcyn0293   pap     cyn    125       0
#  7   papcyn0292   pap     cyn    125       0
#  8   papcyn0297   pap     cyn    125       0
#  9   papcyn0288   pap     cyn    125       0
#  10  papcyn0304   pap     cyn    125       0
#  11  papcyn0305   pap     cyn    125       0
#  12  papcyn0295   pap     cyn    125       0
#  13  papcyn0282   pap     cyn    125       0
#  14  papcyn0302   pap     cyn    125       0
#  15  papcyn0301   pap     cyn    125       0
#  16  papcyn0300   pap     cyn    125       0
#  17  papcyn0298   pap     cyn    125       0
#  18  papcyn0283   pap     cyn    125       0
#  19  papcyn0284   pap     cyn    125       0
#  20  papcyn0287   pap     cyn    125       0
#  21  papcyn0285   pap     cyn    125       0
#  22  papcyn0303   pap     cyn    125       0
#  23  papcyn0296   pap     cyn    125       0
#  24  papcyn0294   pap     cyn    125       0
#  25  pansch0216   pan     sch    125       2
#  26  homsap0688   hom     sap    125       1
#  27  homsap0689   hom     sap    125       1,
#  52:           Tip Genus Species  Clade  Branch
#  0  panpan0342   pan     pan     52       0
#  1  panpan0343   pan     pan     52       0
#  2  panpan0340   pan     pan     52       0
#  3  panpan0341   pan     pan     52       0
#  4  pantro0258   pan     tro     52       0
#  5  pansch0436   pan     sch     52       0
#  6  pansch0435   pan     sch     52       0
#  7  panpan0344   pan     pan     52       0
#  8  pansch0434   pan     sch     52       0
#  9  homsap1886   hom     sap     52       1,
#  172:            Tip Genus Species  Clade  Branch
#  0   pantro0486   pan     tro    172       0
#  1   gorgor0141   gor     gor    172       0
#  2   panpan0686   pan     pan    172       0
#  3   panpan0690   pan     pan    172       0
#  4   panpan0689   pan     pan    172       0
#  5   panpan0687   pan     pan    172       0
#  6   panpan0685   pan     pan    172       0
#  7   panpan0688   pan     pan    172       0
#  8   pantro0488   pan     tro    172       0
#  9   pantro0487   pan     tro    172       0
#  10  homsap4059   hom     sap    172       1
#  11  homsap4060   hom     sap    172       1
#  12  pansch0823   pan     sch    172       0
#  13  pansch0824   pan     sch    172       0
#  14  alopal0045   alo     pal    172       0}

# %% [markdown]
# ## Write output files

# %%
ctl_fp = '/home/jgs286/git_sw/GWideCodeML/example_data/gwcodeml.ctl'
ctl = ''
with open(ctl_fp, 'r') as f:
    for line in f:
        ctl += line

# %%
print(ctl)
# Out:
#       seqfile = seq_file.phy * sequence data filename
#      treefile = tree.nwk      * tree structure file name
#       outfile = out_name           * main result file name
#
#         noisy = 0  * 0,1,2,3,9: how much rubbish on the screen
#       verbose = 0  * 0: concise; 1: detailed, 2: too much
#       runmode = 0  * 0: user tree;  1: semi-automatic;  2: automatic
#                    * 3: StepwiseAddition; (4,5):PerturbationNNI; -2: pairwise
#
#       seqtype = 1  * 1:codons; 2:AAs; 3:codons-->AAs
#     CodonFreq = 2  * 0:1/61 each, 1:F1X4, 2:F3X4, 3:codon table
#        aaDist = 0  * 0:equal, +:geometric; -:linear, 1-6:G1974,Miyata,c,p,v,a
#
#    aaRatefile = dat/wag.dat  * only used for aa seqs with model=empirical(_F)
#                    * dayhoff.dat, jones.dat, wag.dat, mtmam.dat, or your own
#
#         model = 2  * models for codons:
#                        * 0:one, 1:b, 2:2 or more dN/dS ratios for branches
#                    * models for AAs or codon-translated AAs:
#                        * 0:poisson, 1:proportional, 2:Empirical, 3:Empirical+F
#                        * 6:FromCodon, 7:AAClasses, 8:REVaa_0, 9:REVaa(nr=189)
#
#       NSsites = 2  * 0:one w;1:neutral;2:selection; 3:discrete;4:freqs;
#                    * 5:gamma;6:2gamma;7:beta;8:beta&w;9:beta&gamma;
#                    * 10:beta&gamma+1; 11:beta&normal>1; 12:0&2normal>1;
#                    * 13:3normal>0
#
#         icode = 0  * 0:universal code; 1:mammalian mt; 2-10:see below
#     fix_kappa = 0  * 1: kappa fixed, 0: kappa to be estimated
#         kappa = 3  * initial or fixed kappa
#     fix_omega = 0  * 1: omega or omega_1 fixed, 0: estimate
#         omega = .4 * initial or fixed omega, for codons or codon-based AAs
#
#     fix_alpha = 1  * 0: estimate gamma shape parameter; 1: fix it at alpha
#         alpha = 0  * initial or fixed alpha, 0:infinity (constant rate)
#        Malpha = 0  * different alphas for genes
#
#        ncatG = 3   * # of categories in dG of NSsites models
#        clock = 0   * 0:no clock, 1:global clock; 2:local clock; 3:TipDate
#        getSE = 0   * 0: don't want them, 1: want S.E.s of estimates
#
#     RateAncestor = 0  * (0,1,2): rates (alpha>0) or ancestral states (1 or 2)
#       Small_Diff = .5e-6

# %%
ctl_dict = OrderedDict({'seqfile': 'seq_file.phy',
            'treefile': 'tree.nwk',
            'outfile': 'out_name',
            'noisy': 0,
            'verbose': 0,
            'runmode': 0,
            'seqtype': 1,
            'CodonFreq': 2,
            'aaDist': 0,
            'aaRatefile': 'dat/wag.dat',
            'model': 2,
            'NSsites': 2,
            'icode': 0,
            'fix_kappa': 0,
            'kappa': 3,
            'fix_omega': 0,
            'omega': .4,
            'fix_alpha': 1,
            'alpha': 0,
            'Malpha': 0,
            'ncatG': 3,
            'clock': 0,
            'getSE': 0,
            'RateAncestor': 0,
            'Small_Diff': '.5e-6'
})

# %%
makedirs(project_dir, exist_ok=True)

# %%
aln_dir = '/workdir/jgs/projects/primate_codiv/data/renamed/per_gene_alignments'
project_dir = '/home/jgs286/gwcodeml'
cmd_stub = ('gwidecodeml -model {model} '
            '-work_dir {work_dir} '
            '-cds {cds} '
            '-tree {tree} '
            '-dnds '
            '-branch {branch} '
            '-p {p}')

makedirs(project_dir, exist_ok=True)

cmds = []
for clade in rerooted:
    clade_dir = join(project_dir, 'clade_{0:03d}'.format(clade))
    clade_aln_dir = join(aln_dir, 'cluster_{0:03d}_genes'.format(clade))
    
    # copy alignments
#     copytree(clade_aln_dir, clade_dir, dirs_exist_ok=True)
    
    clade_tree = rerooted[clade]
    clade_tree.name = None
    clade_branch_df = host_dfs[clade]
    
    # write branch fp
    branch_fp = join(clade_dir, '{0:03d}_branch.csv'.format(clade))
    clade_branch_df[['Tip','Branch']].to_csv(branch_fp, header=False, index=False)
    
    # write tree fp
    tree_fp = join(clade_dir, '{0:03d}_tree.nwk'.format(clade))
    clade_tree.write(tree_fp)
    
    # write ctl file
    clade_ctl = ctl_dict.copy()
    clade_ctl['outfile'] = 'clade_{0:03d}_out'.format(clade)
    with open(join(clade_dir, 'gwcodeml.ctl'), 'w') as f:
        for item in ctl_dict:
            f.write('{0} = {1}\n'.format(item, ctl_dict[item]))
    
    # write command
    cmd = cmd_stub.format(model='BM',
                          work_dir=clade_dir,
                          cds='.fa',
                          tree=tree_fp,
                          branch=branch_fp,
                          p=64)
    cmd_fp = join(clade_dir, 'run_gwcodeml.{0:03d}.sh'.format(clade))
    
    cmds.append('cd clade_{0:03d}'.format(clade))
    cmds.append('bash run_gwcodeml.{0:03d}.sh'.format(clade))
    cmds.append('cd ..')
    
    with open(cmd_fp, 'w') as f:
        f.write(cmd)
    
with open(join(project_dir, 'run_all.sh'), 'w') as f:
    f.write('\n'.join(cmds))
